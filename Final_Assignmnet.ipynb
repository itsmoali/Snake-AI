# %%
#Importing necessary dependencies
import itertools
import json
import random
import dataclasses
import pygame
import matplotlib.pyplot as plt

# Initializing the Q-tables. It doesnt contain all the states yet, they will be added when they are explored.
sequence = [''.join(s) for s in list(itertools.product(*[['0','1']] * 4))]
widths = ['0','1','NA']
heights = ['2','3','NA']

qtable = {}
for i in widths:
    for j in heights:
        for k in sequence:
            qtable[str((i,j,k))] = [0,0,0,0]

with open("qtable.json", "w") as f:
    json.dump(qtable, f)

# %%
@dataclasses.dataclass
class GameState:
    distance: tuple
    position: tuple
    surroundings: str
    food: tuple

# The class represents the main brain of the agent
class Brain(object):
    def __init__(self, width, height, block_size):
        
        # Represent the pararmeters for the game board
        self.width = width
        self.height = height
        self.block_size = block_size

        # Represent the learning parameters
        self.epsilon = 0.1 
        self.learning_rate = 0.7
        self.discount = 0.5

        # Contains the log of the State/Action pairs and values
        self.qvalues = self.loadqvalues()
        self.log = []


        # Actions that the agent can take
        self.actions = {
            0:'left',
            1:'right',
            2:'up',
            3:'down'
        }
        
    #Resets the log to an empty list
    def reset(self):
        self.log = []

    #Loads the q-values
    def loadqvalues(self, path="qtable.json"):
        with open(path, "r") as f:
            qvalues = json.load(f)
        return qvalues

    #This function decides how the agent should act in a given state and also remebers them.     
    def act(self, snake, food):
        state = self.getstate(snake, food)

        # Chooses a random action
        rand = random.uniform(0,1)
        if rand < self.epsilon:
            action_key = random.choices(list(self.actions.keys()))[0]
        else:
            state_scores = self.qvalues[self.getstateStr(state)]
            action_key = state_scores.index(max(state_scores))
        action_val = self.actions[action_key]
        
        # Remember the actions it took at each state
        self.log.append({
            'state': state,
            'action': action_key
            })
        return action_val
    #Using the Bellman Equation, updates the q-values
    def updateqvalues(self, reason):
        log = self.log[::-1]
        for i, h in enumerate(log[:-1]):
            #If the snake ate itself then we would reward it negatively. 
            #The bellman equation doesnt contain the future reward as the game is over
            if reason == 'Tail': 
                _state = log[0]['state']
                _action = log[0]['action']
                state_str = self.getstateStr(_state)
                reward = -5
                self.qvalues[state_str][_action] = (1-self.learning_rate) * self.qvalues[state_str][_action] +self.learning_rate * reward 
                reason = None
            #If the snake gets killed by going off screen
            #The bellman equation doesnt contain the future reward as the game is over
            elif reason == 'Screen': 
                _state = log[0]['state']
                _action = log[0]['action']
                state_str = self.getstateStr(_state)
                reward = -1
                self.qvalues[state_str][_action] = (1-self.learning_rate) * self.qvalues[state_str][_action] + self.learning_rate * reward 
                reason = None
            #Case where the snake survives
            else:
                # Current state of the snake
                s1 = h['state'] 

                #Previous state of the snake
                s0 = log[i+1]['state'] 
                #Action taken at previous state
                a0 = log[i+1]['action']
                
                #Location in current state
                x1 = s0.distance[0] 
                y1 = s0.distance[1] 
                #Location in previous state
                x2 = s1.distance[0] 
                y2 = s1.distance[1] 

                # Case where the snake would eat the food 
                if s0.food != s1.food: 
                    reward = 10
                #Case where the snake would move closer to the food pallet instead of eating it
                elif (abs(x1) > abs(x2) or abs(y1) > abs(y2)): # Snake is closer to the food, positive reward
                    reward = 1
                #Case where the snake starts to move away from the food pallet
                else:
                    reward = -1
                #The q-values would be updated accordingly   
                state_str = self.getstateStr(s0)
                new_state_str = self.getstateStr(s1)
                # Bellman equation
                self.qvalues[state_str][a0]=(1-self.learning_rate)*(self.qvalues[state_str][a0])+self.learning_rate*(reward+self.discount*max(self.qvalues[new_state_str])) 
    #This function helps in defining the positiong of the snake in the environmnet
    
    def getstate(self, snake, food):
        head = snake[-1]
        #Distance described with respect to the food pallet
        dist_x = food[0] - head[0]
        dist_y = food[1] - head[1]

        if dist_x > 0:
            #Food it to right of the snake
            pos_x = '1' 
        elif dist_x < 0:
            #Food it to left of the snak
            pos_x = '0' 
        else:
            #Snake is in the same direction of the food
            pos_x = 'NA' 

        if dist_y > 0:
            #Food is below snake
            pos_y = '3' 
        elif dist_y < 0:
            #Food is above the snake
            pos_y = '2' 
        else:
            #Snake is in the same direction of the food
            pos_y = 'NA' 
        #Sequence of positions of the snake
        sequences = [
            (head[0]-self.block_size, head[1]),   
            (head[0]+self.block_size, head[1]),         
            (head[0],head[1]-self.block_size),
            (head[0],head[1]+self.block_size),
        ]
        
        surrounding_list = []
        #Describes the environment in relation to the snake. Like where is the screen and where is its tail.
        #Value of 1 would be given for obstacles, and 0 in case nothing dangerous is there.
        for sequence in sequences:
            if sequence[0] < 0 or sequence[1] < 0: 
                surrounding_list.append('1')
            elif sequence[0] >= self.width or sequence[1] >= self.height: 
                surrounding_list.append('1')
            elif sequence in snake[:-1]: 
                surrounding_list.append('1')
            else:
                surrounding_list.append('0')
        surroundings = ''.join(surrounding_list)
        
        return GameState((dist_x, dist_y), (pos_x, pos_y), surroundings, food)

    def getstateStr(self, state):
        return str((state.position[0],state.position[1],state.surroundings))

# %%
#Game code adopted from the following website: https://www.edureka.co/blog/snake-game-with-pygame/

#Represents the game environmnet


pygame.init()

#used the make the game environmnet
YELLOW = (255, 255, 102)
BLACK = (0, 0, 0)
GREEN = (0, 255, 0)
BLUE = (50, 153, 213)

BLOCK_SIZE = 20 
DIS_WIDTH = 400
DIS_HEIGHT = 400

FRAMESPEED = 99999



def GameLoop():
    global dis
    
    dis = pygame.display.set_mode((DIS_WIDTH, DIS_HEIGHT))
    pygame.display.set_caption('Snake')
    clock = pygame.time.Clock()

    # Starting position of snake
    x1 = DIS_WIDTH / 2
    y1 = DIS_HEIGHT / 2
    x1_change = 0
    y1_change = 0
    snake_list = [(x1,y1)]
    length_of_snake = 1

    # Create first food pallet at a random location
    food_posx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 20.0) * 20.0
    food_posy = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 20.0) * 20.0

    dead = False
    reason = None
    while not dead:
        # Get valid actions and implement them
        action = brain.act(snake_list, (food_posx,food_posy))
        if action == "left":
            x1_change = -BLOCK_SIZE
            y1_change = 0
        elif action == "right":
            x1_change = BLOCK_SIZE
            y1_change = 0
        elif action == "up":
            y1_change = -BLOCK_SIZE
            x1_change = 0
        elif action == "down":
            y1_change = BLOCK_SIZE
            x1_change = 0

        # Move the snake
        x1 += x1_change
        y1 += y1_change
        head = (x1,y1)
        snake_list.append(head)

        # Check if snake is off screen, in which case it would be dead
        if x1 >= DIS_WIDTH or x1 < 0 or y1 >= DIS_HEIGHT or y1 < 0:
            reason = 'Screen'
            dead = True

        # Check if snake hit tail, in which case it would be dead

        if len(snake_list) >4:
            if head in snake_list[:-1]:
                reason = 'Tail'
                dead = True

        # Check if snake ate food. If it did then generate a different food pallet
        if x1 == food_posx and y1 == food_posy:
            food_posx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 20.0) * 20.0
            food_posy = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 20.0) * 20.0
            length_of_snake += 1

        # Delete the last cell since we just added a head for moving, unless we ate a food
        if len(snake_list) > length_of_snake:
            del snake_list[0]

        # Draw food, snake and update score
        dis.fill(BLUE)
        DrawFood(food_posx, food_posy)
        DrawSnake(snake_list)
        DrawScore(length_of_snake - 1)
        pygame.display.update()

        # Update Q Table
        brain.updateqvalues(reason)
        
        # Next Frame
        clock.tick(FRAMESPEED)

    return length_of_snake - 1, reason

#Function that draws the food pallets
def DrawFood(food_posx, food_posy):
    pygame.draw.rect(dis, GREEN, [food_posx, food_posy, BLOCK_SIZE, BLOCK_SIZE])   

#Function that shows the score
def DrawScore(score):
    font = pygame.font.SysFont("comicsansms", 35)
    value = font.render(f"Score: {score}", True, YELLOW)
    dis.blit(value, [0, 0])

#Renders the snake
def DrawSnake(snake_list):
    head = snake_list[0]
    for x in snake_list:
        #This allows us to have one different block to differentiate which part is the head
        if x == head:
            pygame.draw.rect(dis, YELLOW, [x[0], x[1], BLOCK_SIZE, BLOCK_SIZE])
        else:
            pygame.draw.rect(dis, BLACK, [x[0], x[1], BLOCK_SIZE, BLOCK_SIZE])




game_count = 0

brain = Brain(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)
results = []

while game_count <400:
    
    brain.reset()
    #We stop it from making random moves
    if game_count > 200:
        brain.epsilon = 0
    else:
        brain.epsilon = 0.1
    score, reason = GameLoop()
    results.append(score)
    #Outputs the game number along with the score and reason of death
    print(f"Games number: {game_count}; Final Score: {score}; Died because of: {reason}") 
    game_count += 1

pygame.quit()
# Out:
# Games number: 0; Final Score: 0; Died because of: Screen
# Games number: 1; Final Score: 3; Died because of: Tail
# Games number: 2; Final Score: 3; Died because of: Tail
# Games number: 3; Final Score: 3; Died because of: Screen
# Games number: 4; Final Score: 3; Died because of: Tail
# Games number: 5; Final Score: 2; Died because of: Screen
# Games number: 6; Final Score: 3; Died because of: Tail
# Games number: 7; Final Score: 3; Died because of: Tail
# Games number: 8; Final Score: 3; Died because of: Tail
# Games number: 9; Final Score: 3; Died because of: Tail
# Games number: 10; Final Score: 3; Died because of: Tail
# Games number: 11; Final Score: 3; Died because of: Tail
# Games number: 12; Final Score: 4; Died because of: Tail
# Games number: 13; Final Score: 3; Died because of: Tail
# Games number: 14; Final Score: 4; Died because of: Tail
# Games number: 15; Final Score: 2; Died because of: Screen
# Games number: 16; Final Score: 4; Died because of: Tail
# Games number: 17; Final Score: 5; Died because of: Tail
# Games number: 18; Final Score: 5; Died because of: Screen
# Games number: 19; Final Score: 3; Died because of: Tail
# Games number: 20; Final Score: 1; Died because of: Screen
# Games number: 21; Final Score: 3; Died because of: Tail
# Games number: 22; Final Score: 1; Died because of: Screen
# Games number: 23; Final Score: 4; Died because of: Tail
# Games number: 24; Final Score: 3; Died because of: Tail
# Games number: 25; Final Score: 6; Died because of: Tail
# Games number: 26; Final Score: 3; Died because of: Tail
# Games number: 27; Final Score: 5; Died because of: Tail
# Games number: 28; Final Score: 1; Died because of: Screen
# Games number: 29; Final Score: 3; Died because of: Tail
# Games number: 30; Final Score: 3; Died because of: Screen
# Games number: 31; Final Score: 3; Died because of: Tail
# Games number: 32; Final Score: 3; Died because of: Tail
# Games number: 33; Final Score: 2; Died because of: Screen
# Games number: 34; Final Score: 3; Died because of: Tail
# Games number: 35; Final Score: 4; Died because of: Tail
# Games number: 36; Final Score: 5; Died because of: Tail
# Games number: 37; Final Score: 5; Died because of: Tail
# Games number: 38; Final Score: 4; Died because of: Tail
# Games number: 39; Final Score: 5; Died because of: Tail
# Games number: 40; Final Score: 3; Died because of: Tail
# Games number: 41; Final Score: 4; Died because of: Tail
# Games number: 42; Final Score: 5; Died because of: Screen
# Games number: 43; Final Score: 3; Died because of: Tail
# Games number: 44; Final Score: 4; Died because of: Tail
# Games number: 45; Final Score: 1; Died because of: Screen
# Games number: 46; Final Score: 1; Died because of: Screen
# Games number: 47; Final Score: 3; Died because of: Tail
# Games number: 48; Final Score: 3; Died because of: Tail
# Games number: 49; Final Score: 4; Died because of: Tail
# Games number: 50; Final Score: 3; Died because of: Screen
# Games number: 51; Final Score: 4; Died because of: Tail
# Games number: 52; Final Score: 5; Died because of: Tail
# Games number: 53; Final Score: 2; Died because of: Screen
# Games number: 54; Final Score: 3; Died because of: Tail
# Games number: 55; Final Score: 5; Died because of: Tail
# Games number: 56; Final Score: 4; Died because of: Tail
# Games number: 57; Final Score: 3; Died because of: Screen
# Games number: 58; Final Score: 3; Died because of: Tail
# Games number: 59; Final Score: 5; Died because of: Tail
# Games number: 60; Final Score: 4; Died because of: Tail
# Games number: 61; Final Score: 4; Died because of: Tail
# Games number: 62; Final Score: 3; Died because of: Tail
# Games number: 63; Final Score: 5; Died because of: Screen
# Games number: 64; Final Score: 7; Died because of: Tail
# Games number: 65; Final Score: 5; Died because of: Tail
# Games number: 66; Final Score: 5; Died because of: Tail
# Games number: 67; Final Score: 7; Died because of: Tail
# Games number: 68; Final Score: 6; Died because of: Screen
# Games number: 69; Final Score: 4; Died because of: Tail
# Games number: 70; Final Score: 4; Died because of: Tail
# Games number: 71; Final Score: 4; Died because of: Tail
# Games number: 72; Final Score: 6; Died because of: Screen
# Games number: 73; Final Score: 9; Died because of: Tail
# Games number: 74; Final Score: 5; Died because of: Tail
# Games number: 75; Final Score: 3; Died because of: Tail
# Games number: 76; Final Score: 8; Died because of: Tail
# Games number: 77; Final Score: 3; Died because of: Tail
# Games number: 78; Final Score: 1; Died because of: Screen
# Games number: 79; Final Score: 4; Died because of: Tail
# Games number: 80; Final Score: 5; Died because of: Tail
# Games number: 81; Final Score: 5; Died because of: Tail
# Games number: 82; Final Score: 5; Died because of: Tail
# Games number: 83; Final Score: 3; Died because of: Tail
# Games number: 84; Final Score: 3; Died because of: Tail
# Games number: 85; Final Score: 3; Died because of: Tail
# Games number: 86; Final Score: 4; Died because of: Tail
# Games number: 87; Final Score: 5; Died because of: Tail
# Games number: 88; Final Score: 5; Died because of: Tail
# Games number: 89; Final Score: 7; Died because of: Tail
# Games number: 90; Final Score: 5; Died because of: Tail
# Games number: 91; Final Score: 5; Died because of: Tail
# Games number: 92; Final Score: 5; Died because of: Tail
# Games number: 93; Final Score: 3; Died because of: Tail
# Games number: 94; Final Score: 3; Died because of: Tail
# Games number: 95; Final Score: 3; Died because of: Tail
# Games number: 96; Final Score: 3; Died because of: Tail
# Games number: 97; Final Score: 5; Died because of: Tail
# Games number: 98; Final Score: 7; Died because of: Tail
# Games number: 99; Final Score: 7; Died because of: Tail
# Games number: 100; Final Score: 3; Died because of: Tail
# Games number: 101; Final Score: 6; Died because of: Tail
# Games number: 102; Final Score: 4; Died because of: Tail
# Games number: 103; Final Score: 8; Died because of: Tail
# Games number: 104; Final Score: 4; Died because of: Tail
# Games number: 105; Final Score: 4; Died because of: Tail
# Games number: 106; Final Score: 6; Died because of: Tail
# Games number: 107; Final Score: 2; Died because of: Screen
# Games number: 108; Final Score: 3; Died because of: Tail
# Games number: 109; Final Score: 3; Died because of: Tail
# Games number: 110; Final Score: 6; Died because of: Tail
# Games number: 111; Final Score: 3; Died because of: Tail
# Games number: 112; Final Score: 7; Died because of: Tail
# Games number: 113; Final Score: 4; Died because of: Tail
# Games number: 114; Final Score: 5; Died because of: Tail
# Games number: 115; Final Score: 3; Died because of: Tail
# Games number: 116; Final Score: 4; Died because of: Tail
# Games number: 117; Final Score: 3; Died because of: Screen
# Games number: 118; Final Score: 5; Died because of: Tail
# Games number: 119; Final Score: 4; Died because of: Tail
# Games number: 120; Final Score: 3; Died because of: Tail
# Games number: 121; Final Score: 6; Died because of: Tail
# Games number: 122; Final Score: 4; Died because of: Tail
# Games number: 123; Final Score: 4; Died because of: Tail
# Games number: 124; Final Score: 4; Died because of: Tail
# Games number: 125; Final Score: 5; Died because of: Tail
# Games number: 126; Final Score: 4; Died because of: Tail
# Games number: 127; Final Score: 3; Died because of: Tail
# Games number: 128; Final Score: 3; Died because of: Tail
# Games number: 129; Final Score: 3; Died because of: Tail
# Games number: 130; Final Score: 2; Died because of: Screen
# Games number: 131; Final Score: 5; Died because of: Tail
# Games number: 132; Final Score: 1; Died because of: Screen
# Games number: 133; Final Score: 3; Died because of: Tail
# Games number: 134; Final Score: 4; Died because of: Tail
# Games number: 135; Final Score: 7; Died because of: Tail
# Games number: 136; Final Score: 6; Died because of: Screen
# Games number: 137; Final Score: 3; Died because of: Tail
# Games number: 138; Final Score: 3; Died because of: Tail
# Games number: 139; Final Score: 9; Died because of: Screen
# Games number: 140; Final Score: 8; Died because of: Tail
# Games number: 141; Final Score: 3; Died because of: Tail
# Games number: 142; Final Score: 6; Died because of: Tail
# Games number: 143; Final Score: 5; Died because of: Tail
# Games number: 144; Final Score: 5; Died because of: Tail
# Games number: 145; Final Score: 3; Died because of: Tail
# Games number: 146; Final Score: 4; Died because of: Tail
# Games number: 147; Final Score: 9; Died because of: Tail
# Games number: 148; Final Score: 1; Died because of: Screen
# Games number: 149; Final Score: 2; Died because of: Screen
# Games number: 150; Final Score: 3; Died because of: Screen
# Games number: 151; Final Score: 3; Died because of: Tail
# Games number: 152; Final Score: 4; Died because of: Tail
# Games number: 153; Final Score: 2; Died because of: Screen
# Games number: 154; Final Score: 4; Died because of: Tail
# Games number: 155; Final Score: 4; Died because of: Tail
# Games number: 156; Final Score: 12; Died because of: Tail
# Games number: 157; Final Score: 6; Died because of: Tail
# Games number: 158; Final Score: 3; Died because of: Tail
# Games number: 159; Final Score: 3; Died because of: Tail
# Games number: 160; Final Score: 6; Died because of: Tail
# Games number: 161; Final Score: 4; Died because of: Tail
# Games number: 162; Final Score: 2; Died because of: Screen
# Games number: 163; Final Score: 5; Died because of: Tail
# Games number: 164; Final Score: 3; Died because of: Tail
# Games number: 165; Final Score: 5; Died because of: Tail
# Games number: 166; Final Score: 7; Died because of: Tail
# Games number: 167; Final Score: 7; Died because of: Tail
# Games number: 168; Final Score: 5; Died because of: Tail
# Games number: 169; Final Score: 4; Died because of: Tail
# Games number: 170; Final Score: 5; Died because of: Tail
# Games number: 171; Final Score: 3; Died because of: Tail
# Games number: 172; Final Score: 3; Died because of: Tail
# Games number: 173; Final Score: 4; Died because of: Tail
# Games number: 174; Final Score: 3; Died because of: Tail
# Games number: 175; Final Score: 4; Died because of: Tail
# Games number: 176; Final Score: 7; Died because of: Tail
# Games number: 177; Final Score: 3; Died because of: Tail
# Games number: 178; Final Score: 4; Died because of: Screen
# Games number: 179; Final Score: 4; Died because of: Tail
# Games number: 180; Final Score: 4; Died because of: Tail
# Games number: 181; Final Score: 4; Died because of: Screen
# Games number: 182; Final Score: 7; Died because of: Tail
# Games number: 183; Final Score: 5; Died because of: Tail
# Games number: 184; Final Score: 8; Died because of: Tail
# Games number: 185; Final Score: 7; Died because of: Tail
# Games number: 186; Final Score: 6; Died because of: Tail
# Games number: 187; Final Score: 3; Died because of: Tail
# Games number: 188; Final Score: 10; Died because of: Tail
# Games number: 189; Final Score: 6; Died because of: Tail
# Games number: 190; Final Score: 4; Died because of: Tail
# Games number: 191; Final Score: 3; Died because of: Tail
# Games number: 192; Final Score: 5; Died because of: Tail
# Games number: 193; Final Score: 3; Died because of: Tail
# Games number: 194; Final Score: 4; Died because of: Screen
# Games number: 195; Final Score: 5; Died because of: Tail
# Games number: 196; Final Score: 3; Died because of: Tail
# Games number: 197; Final Score: 3; Died because of: Tail
# Games number: 198; Final Score: 3; Died because of: Screen
# Games number: 199; Final Score: 3; Died because of: Tail
# Games number: 200; Final Score: 3; Died because of: Tail
# Games number: 201; Final Score: 8; Died because of: Tail
# Games number: 202; Final Score: 11; Died because of: Tail
# Games number: 203; Final Score: 9; Died because of: Tail
# Games number: 204; Final Score: 3; Died because of: Tail
# Games number: 205; Final Score: 6; Died because of: Tail
# Games number: 206; Final Score: 23; Died because of: Tail
# Games number: 207; Final Score: 31; Died because of: Tail
# Games number: 208; Final Score: 24; Died because of: Tail
# Games number: 209; Final Score: 13; Died because of: Tail
# Games number: 210; Final Score: 32; Died because of: Tail
# Games number: 211; Final Score: 9; Died because of: Tail
# Games number: 212; Final Score: 11; Died because of: Tail
# Games number: 213; Final Score: 7; Died because of: Tail
# Games number: 214; Final Score: 19; Died because of: Tail
# Games number: 215; Final Score: 17; Died because of: Tail
# Games number: 216; Final Score: 15; Died because of: Tail
# Games number: 217; Final Score: 9; Died because of: Tail
# Games number: 218; Final Score: 6; Died because of: Tail
# Games number: 219; Final Score: 9; Died because of: Tail
# Games number: 220; Final Score: 12; Died because of: Tail
# Games number: 221; Final Score: 3; Died because of: Screen
# Games number: 222; Final Score: 15; Died because of: Tail
# Games number: 223; Final Score: 12; Died because of: Tail
# Games number: 224; Final Score: 18; Died because of: Tail
# Games number: 225; Final Score: 4; Died because of: Tail
# Games number: 226; Final Score: 11; Died because of: Tail
# Games number: 227; Final Score: 21; Died because of: Tail
# Games number: 228; Final Score: 5; Died because of: Tail
# Games number: 229; Final Score: 12; Died because of: Tail
# Games number: 230; Final Score: 16; Died because of: Tail
# Games number: 231; Final Score: 19; Died because of: Tail
# Games number: 232; Final Score: 20; Died because of: Tail
# Games number: 233; Final Score: 22; Died because of: Tail
# Games number: 234; Final Score: 28; Died because of: Tail
# Games number: 235; Final Score: 10; Died because of: Tail
# Games number: 236; Final Score: 16; Died because of: Tail
# Games number: 237; Final Score: 22; Died because of: Screen
# Games number: 238; Final Score: 15; Died because of: Tail
# Games number: 239; Final Score: 17; Died because of: Tail
# Games number: 240; Final Score: 20; Died because of: Tail
# Games number: 241; Final Score: 9; Died because of: Tail
# Games number: 242; Final Score: 12; Died because of: Tail
# Games number: 243; Final Score: 17; Died because of: Tail
# Games number: 244; Final Score: 27; Died because of: Tail
# Games number: 245; Final Score: 15; Died because of: Tail
# Games number: 246; Final Score: 8; Died because of: Tail
# Games number: 247; Final Score: 22; Died because of: Tail
# Games number: 248; Final Score: 20; Died because of: Tail
# Games number: 249; Final Score: 16; Died because of: Tail
# Games number: 250; Final Score: 4; Died because of: Screen
# Games number: 251; Final Score: 13; Died because of: Tail
# Games number: 252; Final Score: 18; Died because of: Tail
# Games number: 253; Final Score: 11; Died because of: Tail
# Games number: 254; Final Score: 21; Died because of: Tail
# Games number: 255; Final Score: 8; Died because of: Screen
# Games number: 256; Final Score: 11; Died because of: Tail
# Games number: 257; Final Score: 17; Died because of: Screen
# Games number: 258; Final Score: 27; Died because of: Tail
# Games number: 259; Final Score: 12; Died because of: Tail
# Games number: 260; Final Score: 22; Died because of: Tail
# Games number: 261; Final Score: 17; Died because of: Tail
# Games number: 262; Final Score: 33; Died because of: Tail
# Games number: 263; Final Score: 19; Died because of: Tail
# Games number: 264; Final Score: 13; Died because of: Tail
# Games number: 265; Final Score: 22; Died because of: Tail
# Games number: 266; Final Score: 27; Died because of: Tail
# Games number: 267; Final Score: 21; Died because of: Tail
# Games number: 268; Final Score: 12; Died because of: Tail
# Games number: 269; Final Score: 20; Died because of: Tail
# Games number: 270; Final Score: 13; Died because of: Tail
# Games number: 271; Final Score: 23; Died because of: Tail
# Games number: 272; Final Score: 21; Died because of: Tail
# Games number: 273; Final Score: 31; Died because of: Tail
# Games number: 274; Final Score: 31; Died because of: Tail
# Games number: 275; Final Score: 13; Died because of: Tail
# Games number: 276; Final Score: 27; Died because of: Tail
# Games number: 277; Final Score: 23; Died because of: Tail
# Games number: 278; Final Score: 24; Died because of: Tail
# Games number: 279; Final Score: 20; Died because of: Tail
# Games number: 280; Final Score: 13; Died because of: Tail
# Games number: 281; Final Score: 10; Died because of: Tail
# Games number: 282; Final Score: 13; Died because of: Tail
# Games number: 283; Final Score: 26; Died because of: Tail
# Games number: 284; Final Score: 10; Died because of: Tail
# Games number: 285; Final Score: 18; Died because of: Tail
# Games number: 286; Final Score: 24; Died because of: Tail
# Games number: 287; Final Score: 17; Died because of: Tail
# Games number: 288; Final Score: 18; Died because of: Tail
# Games number: 289; Final Score: 49; Died because of: Tail
# Games number: 290; Final Score: 20; Died because of: Tail
# Games number: 291; Final Score: 17; Died because of: Tail
# Games number: 292; Final Score: 30; Died because of: Tail
# Games number: 293; Final Score: 23; Died because of: Tail
# Games number: 294; Final Score: 21; Died because of: Tail
# Games number: 295; Final Score: 19; Died because of: Tail
# Games number: 296; Final Score: 17; Died because of: Tail
# Games number: 297; Final Score: 25; Died because of: Tail
# Games number: 298; Final Score: 12; Died because of: Tail
# Games number: 299; Final Score: 19; Died because of: Tail
# Games number: 300; Final Score: 35; Died because of: Tail
# Games number: 301; Final Score: 32; Died because of: Tail
# Games number: 302; Final Score: 28; Died because of: Tail
# Games number: 303; Final Score: 23; Died because of: Tail
# Games number: 304; Final Score: 6; Died because of: Tail
# Games number: 305; Final Score: 17; Died because of: Tail
# Games number: 306; Final Score: 15; Died because of: Tail
# Games number: 307; Final Score: 25; Died because of: Tail
# Games number: 308; Final Score: 32; Died because of: Tail
# Games number: 309; Final Score: 21; Died because of: Tail
# Games number: 310; Final Score: 19; Died because of: Tail
# Games number: 311; Final Score: 32; Died because of: Tail
# Games number: 312; Final Score: 30; Died because of: Tail
# Games number: 313; Final Score: 21; Died because of: Tail
# Games number: 314; Final Score: 5; Died because of: Tail
# Games number: 315; Final Score: 31; Died because of: Screen
# Games number: 316; Final Score: 27; Died because of: Screen
# Games number: 317; Final Score: 19; Died because of: Tail
# Games number: 318; Final Score: 15; Died because of: Tail
# Games number: 319; Final Score: 10; Died because of: Tail
# Games number: 320; Final Score: 28; Died because of: Tail
# Games number: 321; Final Score: 34; Died because of: Tail
# Games number: 322; Final Score: 24; Died because of: Tail
# Games number: 323; Final Score: 50; Died because of: Tail
# Games number: 324; Final Score: 24; Died because of: Tail
# Games number: 325; Final Score: 31; Died because of: Tail
# Games number: 326; Final Score: 11; Died because of: Tail
# Games number: 327; Final Score: 37; Died because of: Screen
# Games number: 328; Final Score: 24; Died because of: Tail
# Games number: 329; Final Score: 13; Died because of: Screen
# Games number: 330; Final Score: 28; Died because of: Tail
# Games number: 331; Final Score: 20; Died because of: Tail
# Games number: 332; Final Score: 28; Died because of: Tail
# Games number: 333; Final Score: 15; Died because of: Screen
# Games number: 334; Final Score: 23; Died because of: Tail
# Games number: 335; Final Score: 32; Died because of: Tail
# Games number: 336; Final Score: 12; Died because of: Screen
# Games number: 337; Final Score: 25; Died because of: Screen
# Games number: 338; Final Score: 23; Died because of: Tail
# Games number: 339; Final Score: 23; Died because of: Tail
# Games number: 340; Final Score: 51; Died because of: Tail
# Games number: 341; Final Score: 20; Died because of: Tail
# Games number: 342; Final Score: 17; Died because of: Screen
# Games number: 343; Final Score: 17; Died because of: Tail
# Games number: 344; Final Score: 20; Died because of: Tail
# Games number: 345; Final Score: 22; Died because of: Tail
# Games number: 346; Final Score: 37; Died because of: Tail
# Games number: 347; Final Score: 29; Died because of: Tail
# Games number: 348; Final Score: 15; Died because of: Tail
# Games number: 349; Final Score: 18; Died because of: Tail
# Games number: 350; Final Score: 35; Died because of: Tail
# Games number: 351; Final Score: 9; Died because of: Tail
# Games number: 352; Final Score: 16; Died because of: Tail
# Games number: 353; Final Score: 29; Died because of: Screen
# Games number: 354; Final Score: 35; Died because of: Tail
# Games number: 355; Final Score: 26; Died because of: Tail
# Games number: 356; Final Score: 16; Died because of: Tail
# Games number: 357; Final Score: 30; Died because of: Tail
# Games number: 358; Final Score: 24; Died because of: Tail
# Games number: 359; Final Score: 42; Died because of: Tail
# Games number: 360; Final Score: 32; Died because of: Tail
# Games number: 361; Final Score: 12; Died because of: Tail
# Games number: 362; Final Score: 10; Died because of: Tail
# Games number: 363; Final Score: 17; Died because of: Tail
# Games number: 364; Final Score: 31; Died because of: Tail
# Games number: 365; Final Score: 46; Died because of: Tail
# Games number: 366; Final Score: 36; Died because of: Tail
# Games number: 367; Final Score: 43; Died because of: Screen
# Games number: 368; Final Score: 22; Died because of: Tail
# Games number: 369; Final Score: 25; Died because of: Tail
# Games number: 370; Final Score: 29; Died because of: Tail
# Games number: 371; Final Score: 47; Died because of: Tail
# Games number: 372; Final Score: 19; Died because of: Tail
# Games number: 373; Final Score: 32; Died because of: Tail
# Games number: 374; Final Score: 20; Died because of: Tail
# Games number: 375; Final Score: 45; Died because of: Tail
# Games number: 376; Final Score: 46; Died because of: Tail
# Games number: 377; Final Score: 27; Died because of: Tail
# Games number: 378; Final Score: 26; Died because of: Tail
# Games number: 379; Final Score: 16; Died because of: Tail
# Games number: 380; Final Score: 17; Died because of: Tail
# Games number: 381; Final Score: 23; Died because of: Tail
# Games number: 382; Final Score: 18; Died because of: Tail
# Games number: 383; Final Score: 20; Died because of: Tail
# Games number: 384; Final Score: 42; Died because of: Tail
# Games number: 385; Final Score: 12; Died because of: Tail
# Games number: 386; Final Score: 13; Died because of: Tail
# Games number: 387; Final Score: 19; Died because of: Tail
# Games number: 388; Final Score: 40; Died because of: Tail
# Games number: 389; Final Score: 41; Died because of: Tail
# Games number: 390; Final Score: 33; Died because of: Tail
# Games number: 391; Final Score: 37; Died because of: Tail
# Games number: 392; Final Score: 47; Died because of: Tail
# Games number: 393; Final Score: 17; Died because of: Tail
# Games number: 394; Final Score: 28; Died because of: Tail
# Games number: 395; Final Score: 28; Died because of: Tail
# Games number: 396; Final Score: 22; Died because of: Tail
# Games number: 397; Final Score: 24; Died because of: Screen

# %%
plt.plot(results)
plt.xlabel("Number of Games")
plt.ylabel("Score")
plt.title('Performance Measure')
plt.show()
print('Parameters used: Learning rate = 0.7  Discount Rate = 0.5')
